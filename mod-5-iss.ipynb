# %%
import json
import urllib.request
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

lat_list=[]
lon_list=[]
timestamp_list=[]

for i in range(200):
    url = "http://api.open-notify.org/iss-now.json"
    response = urllib.request.urlopen(url)
    result = json.loads(response.read())

    location = result["iss_position"]
    timestamp = result['timestamp']
    lat = location['latitude']
    lon = location['longitude']
  
    lat = float(lat)
    lon = float(lon)
    
    lat_list.append(lat)
    lon_list.append(lon)
    timestamp_list.append(timestamp)

    time.sleep(10)
    
d = {'latitude': lat_list, 'longitude': lon_list, 'timestamp': timestamp_list}
df = pd.DataFrame(data=d)
df
# Out:
#      latitude  longitude   timestamp
# 0    -50.4492   -20.8018  1657120798
# 1    -50.5955   -19.8034  1657120808
# 2    -50.7324   -18.7992  1657120819
# 3    -50.8597   -17.7890  1657120829
# 4    -50.9776   -16.7733  1657120840
# ..        ...        ...         ...
# 195   25.4435    99.0438  1657122866
# 196   25.9369    99.5197  1657122876
# 197   26.4285   100.0000  1657122887
# 198   26.9415   100.5081  1657122898
# 199   27.4297   100.9984  1657122908
#
# [200 rows x 3 columns]

# %%
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot()
ax.scatter(lat_list,lon_list, color="red")
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('ISS Position')
ax.set_xlim([-90, 90])
ax.set_xlim([-180, 180])
# Out:
# (-180.0, 180.0)
